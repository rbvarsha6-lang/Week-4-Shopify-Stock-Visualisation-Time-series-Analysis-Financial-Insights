# %%
#Import
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-a5bdf1dd-5759-4e21-b979-6ac398312bf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5bdf1dd-5759-4e21-b979-6ac398312bf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Missing values,duplicate handling,data types,standardizing formats,summary statistics,outlier detection.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv(r"shopify data 2025.csv")

# %% [markdown]
# Data Cleaning-Missing values,duplicates and data type

# %%
#data Cleaning-Missing values,duplicates and data type

df.head()
# Out:
#                         date   open   high    low  close  adj_close     volume
# 0  2015-05-21 00:00:00-04:00  2.800  2.874  2.411  2.568      2.568  123039000
# 1  2015-05-22 00:00:00-04:00  2.607  3.110  2.600  2.831      2.831   28412000
# 2  2015-05-26 00:00:00-04:00  2.980  3.034  2.908  2.965      2.965    8202000
# 3  2015-05-27 00:00:00-04:00  3.067  3.081  2.700  2.750      2.750    7976000
# 4  2015-05-28 00:00:00-04:00  2.755  2.774  2.648  2.745      2.745    4000000

# %%
df.tail()
# Out:
#                            date       open       high        low      close  \
# 2464  2025-03-10 00:00:00-04:00  96.070000  96.186996  91.690002  92.750000
# 2465  2025-03-11 00:00:00-04:00  92.750000  95.109001  91.150002  92.949997
# 2466  2025-03-12 00:00:00-04:00  96.669998  99.135002  95.290001  96.529999
# 2467  2025-03-13 00:00:00-04:00  95.169998  95.529999  89.099998  90.589996
# 2468  2025-03-14 00:00:00-04:00  94.610001  95.830002  93.059998  94.849998
#
#       adj_close    volume
# 2464  92.750000  16385300
# 2465  92.949997  12127100
# 2466  96.529999   8531900
# 2467  90.589996  11076400
# 2468  94.849998   7060700

# %%
df.shape
# Out:
# (2469, 7)

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2469 entries, 0 to 2468
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2469 non-null   object
#  1   open       2469 non-null   float64
#  2   high       2469 non-null   float64
#  3   low        2469 non-null   float64
#  4   close      2469 non-null   float64
#  5   adj_close  2469 non-null   float64
#  6   volume     2469 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 135.2+ KB

# %%
#Descriptive preparation time series

df.describe()
# Out:
#               open         high          low        close    adj_close  \
# count  2469.000000  2469.000000  2469.000000  2469.000000  2469.000000
# mean     48.464345    49.505495    47.347795    48.456613    48.456613
# std      43.633916    44.470235    42.642546    43.573362    43.573362
# min       1.939000     1.985000     1.848000     1.933000     1.933000
# 25%      10.479000    10.635000    10.275000    10.450000    10.450000
# 50%      35.640999    36.879002    34.655998    35.874001    35.874001
# 75%      76.080002    77.169998    74.589996    75.800003    75.800003
# max     171.800003   176.291794   168.509506   169.059998   169.059998
#
#              volume
# count  2.469000e+03
# mean   1.657049e+07
# std    1.436909e+07
# min    1.039000e+06
# 25%    8.098000e+06
# 50%    1.275860e+07
# 75%    2.060200e+07
# max    2.089590e+08

# %%
df.isnull().sum()
# Out:
# date         0
# open         0
# high         0
# low          0
# close        0
# adj_close    0
# volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["date"] = pd.to_datetime(df["date"])
# Out:
# /tmp/ipykernel_1274/3228555721.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df["date"] = pd.to_datetime(df["date"])

# %%
df =df.sort_values("date")

# %%
df =df.set_index("date")

# %%
plt.figure(figsize=(12,5))

sns.lineplot(
    data=df,
    x=df.index,
    y="close"
)
plt.title("Shopify Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")

plt.show()

# %%
plt.figure(figsize=(12,5))

sns.lineplot(
    data=df,
    x=df.index,
    y="open"
)
plt.title("Shopify Opening Price Over Time")
plt.xlabel("Date")
plt.ylabel("Opening Price")

plt.show()

# %%
plt.plot(df['high'], label='high')
plt.plot(df['low'], label='low')
plt.plot(df['open'], label='open')
plt.plot(df['close'], label='close')


plt.xlabel('Days')
plt.ylabel('Price')
plt.title('High, Low, Open and Close')
plt.show()

# %%
plt.figure(figsize=(14,6))

sns.lineplot(data=df, x=df.index, y="open", label="open")
sns.lineplot(data=df, x=df.index, y="high", label="high")
sns.lineplot(data=df, x=df.index, y="low", label="low")
sns.lineplot(data=df, x=df.index, y="close", label="close")

plt.title("Shopify OHLC Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price")

plt.show()

# %%
plt.figure(figsize=(14,5))
sns.lineplot(data=df, x="date", y="volume")
plt.title("Shopify Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Trading Volume")
plt.show()

# %%
df.nlargest(5,"volume")
# Out:
#                              open    high     low   close  adj_close  \
# date
# 2017-10-04 00:00:00-04:00  11.683  11.693  10.075  10.330     10.330
# 2017-10-05 00:00:00-04:00   9.753  10.343   9.331  10.043     10.043
# 2017-10-31 00:00:00-04:00  10.138  10.481   9.451   9.949      9.949
# 2015-05-21 00:00:00-04:00   2.800   2.874   2.411   2.568      2.568
# 2017-10-10 00:00:00-04:00   9.727   9.900   8.935   9.257      9.257
#
#                               volume
# date
# 2017-10-04 00:00:00-04:00  208959000
# 2017-10-05 00:00:00-04:00  197807000
# 2017-10-31 00:00:00-04:00  129271000
# 2015-05-21 00:00:00-04:00  123039000
# 2017-10-10 00:00:00-04:00  113732000

# %%
df["daily price change"] = df["close"]- df["open"]
df["daily price change"]
# Out:
# date
# 2015-05-21 00:00:00-04:00   -0.232000
# 2015-05-22 00:00:00-04:00    0.224000
# 2015-05-26 00:00:00-04:00   -0.015000
# 2015-05-27 00:00:00-04:00   -0.317000
# 2015-05-28 00:00:00-04:00   -0.010000
#                                ...
# 2025-03-10 00:00:00-04:00   -3.320000
# 2025-03-11 00:00:00-04:00    0.199997
# 2025-03-12 00:00:00-04:00   -0.139999
# 2025-03-13 00:00:00-04:00   -4.580002
# 2025-03-14 00:00:00-04:00    0.239998
# Name: daily price change, Length: 2469, dtype: float64

# %%
plt.figure(figsize=(14,5))

sns.scatterplot(
    data=df,
    x="volume",
    y="daily price change"
)

plt.title("Trading volume vs daily price change")
plt.xlabel("Volume")  # xlable -> xlabel
plt.ylabel("Daily price change")  # ylable -> ylabel

plt.show()

# %%
#volume vs daily price range
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="volume",
    y="daily price change"
)

plt.title(" volume vs daily price range")
plt.xlabel("Volume")  # xlable -> xlabel
plt.ylabel("Daily price range")  # ylable -> ylabel

plt.show()

# %%
#calculate the 20-Day SMA

df["SMA_20"] = df["close"].rolling (window=20).mean()
df["SMA_20"]
# Out:
# date
# 2015-05-21 00:00:00-04:00           NaN
# 2015-05-22 00:00:00-04:00           NaN
# 2015-05-26 00:00:00-04:00           NaN
# 2015-05-27 00:00:00-04:00           NaN
# 2015-05-28 00:00:00-04:00           NaN
#                                 ...
# 2025-03-10 00:00:00-04:00    114.415001
# 2025-03-11 00:00:00-04:00    113.067500
# 2025-03-12 00:00:00-04:00    111.714500
# 2025-03-13 00:00:00-04:00    110.219500
# 2025-03-14 00:00:00-04:00    108.579500
# Name: SMA_20, Length: 2469, dtype: float64

# %%
#plot Closing Price + 20_Day SMA
plt.figure(figsize=(14,6))

sns.lineplot(data=df, x=df.index, y="close", label="Closing Price")
sns.lineplot(data=df, x=df.index, y="SMA_20", label="20-Day SMA")

plt.title("Shopify Closing Price and 20-Day SMA")
plt.xlabel("Date")
plt.ylabel("Price")

plt.show()

# %%
#calculate the 50-Day SMA

df["SMA_50"] = df["close"].rolling (window=50).mean()
df["SMA_50"]
# Out:
# date
# 2015-05-21 00:00:00-04:00         NaN
# 2015-05-22 00:00:00-04:00         NaN
# 2015-05-26 00:00:00-04:00         NaN
# 2015-05-27 00:00:00-04:00         NaN
# 2015-05-28 00:00:00-04:00         NaN
#                                ...
# 2025-03-10 00:00:00-04:00    111.7678
# 2025-03-11 00:00:00-04:00    111.4232
# 2025-03-12 00:00:00-04:00    111.1546
# 2025-03-13 00:00:00-04:00    110.8028
# 2025-03-14 00:00:00-04:00    110.5660
# Name: SMA_50, Length: 2469, dtype: float64

# %%
#plot Closing Price + 50_Day SMA
plt.figure(figsize=(14,6))

sns.lineplot(data=df, x=df.index, y="close", label="Closing Price")
sns.lineplot(data=df, x=df.index, y="SMA_50", label="50-Day SMA")

plt.title("Shopify Closing Price and 50-Day SMA")
plt.xlabel("Date")
plt.ylabel("Price")

plt.show()

# %%
#plot Close + Both Moving Averages

plt.figure(figsize=(14,6))
sns.lineplot(data=df, x=df.index, y="close", label="Closing Price")
sns.lineplot(data=df, x=df.index, y="SMA_20", label="20-Day SMA")
sns.lineplot(data=df, x=df.index, y="SMA_50", label="50-Day SMA")

plt.title("Shopify Closing Price and Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price")

plt.show()

# %%
df["daily return%"] = ((df["close"] - df["open"]) / df["open"]) * 100
df["daily return%"].head()
# Out:
# date
# 2015-05-21 00:00:00-04:00    -8.285710
# 2015-05-22 00:00:00-04:00     8.592250
# 2015-05-26 00:00:00-04:00    -0.503359
# 2015-05-27 00:00:00-04:00   -10.335830
# 2015-05-28 00:00:00-04:00    -0.362985
# Name: daily return%, dtype: float64

# %%
#daily return%

df["daily return%"] = ((df["close"] - df["open"]) / df["open"]) * 100

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=df, x="daily return%", bins=20)

plt.title("Distribution of Daily Return%")
plt.xlabel("Daily Return%")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=df, x="daily return%", bins=20,kde=True) #Kernel density estimate

plt.title("Distribution of Daily Return%")
plt.xlabel("Daily Return%")
plt.ylabel("Frequency")

plt.show()

# %%
#volatility
df["Absolute Return"] = df["daily return%"].abs()
df["Absolute Return"]
# Out:
# date
# 2015-05-21 00:00:00-04:00     8.285710
# 2015-05-22 00:00:00-04:00     8.592250
# 2015-05-26 00:00:00-04:00     0.503359
# 2015-05-27 00:00:00-04:00    10.335830
# 2015-05-28 00:00:00-04:00     0.362985
#                                ...
# 2025-03-10 00:00:00-04:00     3.455813
# 2025-03-11 00:00:00-04:00     0.215630
# 2025-03-12 00:00:00-04:00     0.144822
# 2025-03-13 00:00:00-04:00     4.812443
# 2025-03-14 00:00:00-04:00     0.253671
# Name: Absolute Return, Length: 2469, dtype: float64

# %%
df.nlargest(10,"Absolute Return")
# Out:
#                                  open        high        low      close  \
# date
# 2022-03-18 00:00:00-04:00   64.987999   78.000000  64.730003  78.000000
# 2015-09-17 00:00:00-04:00    2.989000    3.795000   2.985000   3.555000
# 2022-02-24 00:00:00-05:00   58.502998   66.878998  58.502998  66.398003
# 2022-05-12 00:00:00-04:00   31.361000   38.500000  30.806000  35.351002
# 2022-07-20 00:00:00-04:00   34.189999   38.840000  33.950001  38.490002
# 2022-01-24 00:00:00-05:00   83.400002   96.399002  78.000000  93.848999
# 2022-01-21 00:00:00-05:00  100.469002  101.363998  86.875000  88.211998
# 2022-07-27 00:00:00-04:00   31.459999   35.480000  31.309999  35.240002
# 2017-10-04 00:00:00-04:00   11.683000   11.693000  10.075000  10.330000
# 2022-04-20 00:00:00-04:00   59.298000   59.400002  52.500000  52.500000
#
#                            adj_close     volume  daily price change  \
# date
# 2022-03-18 00:00:00-04:00  78.000000   46309000           13.012001
# ...

# %%
plt.figure(figsize=(14,5))
sns.lineplot(data=df, x="date", y="daily return%")
plt.axhline(0,linestyle="--")
plt.xlabel("Date")
plt.ylabel("Daily Return%")
plt.title("Shopify daily returns over time")

plt.show()
